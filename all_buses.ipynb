# %%
# !pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Users\sures\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\sures\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\sures\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\sures\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (c:\Users\sures\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\sures\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\sures\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (c:\Users\sures\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as Ec
from  selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
import time

# %%
import pandas as pd 
a=pd.read_csv(r"D:\project\andra_routs.csv")
a
a.count()
# Out:
# andra_keys      49
# andra_routes    49
# dtype: int64

# %%
new=pd.read_csv(r"D:\project\andra_routs.csv")
new
# Out:
#                                            andra_keys  \
# 0   https://www.redbus.in/bus-tickets/vijayawada-t...
# 1   https://www.redbus.in/bus-tickets/hyderabad-to...
# 2   https://www.redbus.in/bus-tickets/kakinada-to-...
# 3   https://www.redbus.in/bus-tickets/visakhapatna...
# 4   https://www.redbus.in/bus-tickets/chittoor-and...
# 5   https://www.redbus.in/bus-tickets/kadapa-to-ba...
# 6   https://www.redbus.in/bus-tickets/ananthapur-t...
# 7   https://www.redbus.in/bus-tickets/tirupathi-to...
# 8   https://www.redbus.in/bus-tickets/visakhapatna...
# 9   https://www.redbus.in/bus-tickets/ongole-to-hy...
# 10  https://www.redbus.in/bus-tickets/bangalore-to...
# 11  https://www.redbus.in/bus-tickets/macherla-to-...
# 12  https://www.redbus.in/bus-tickets/rajahmundry-...
# 13  https://www.redbus.in/bus-tickets/nandyala-to-...
# 14  https://www.redbus.in/bus-tickets/bangalore-to...
# 15  https://www.redbus.in/bus-tickets/hyderabad-to...
# ...

# %%
#--------------------------------------------------------Andra details------------------------------------------------------------

driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

ap_bus_name=[]
ap_bus_type=[]
ap_bus_departing_time=[]
ap_bus_duration=[]
ap_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in a.iterrows():
    links=k["andra_keys"]
    routs=k["andra_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)
    for website in websites:
        website.click()
        time.sleep(2)
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='button']"))
        inside.click()
    except:
       print("button not available")
    time.sleep(3)
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(10, document.body.scrollHeight);")
        time.sleep(8) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        #time.sleep(2)
    bus_name=driver.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//div[@class='clearfix row-one']//div[@class='column-six p-right-10 w-10 fl']")    
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")     
    for bus in bus_name:
        ap_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        ap_bus_type.append(bus_types.text)
    for starting_times in starting:
        ap_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        ap_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        ap_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")
# Out:
# button not available
# button not available
# success

# %%
data1={
"bus_name":ap_bus_name,
"bus_type":ap_bus_type,
"starting_time":ap_bus_departing_time,
"time_duration":ap_bus_duration,
"reaching_time":ap_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
andra=pd.DataFrame(data1)
location=r"D:\total project\andra_routes.csv"
andra.to_csv(location,index=False)

# %%
l=pd.read_csv(r"D:\total project\andra.csv")
l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3486 entries, 0 to 3485
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bus_name       3429 non-null   object
#  1   bus_type       3429 non-null   object
#  2   starting_time  3429 non-null   object
#  3   time_duration  3429 non-null   object
#  4   reaching_time  3429 non-null   object
#  5   rating         3429 non-null   object
#  6   fair_price     3429 non-null   object
#  7   seats          3429 non-null   object
#  8   route_name     3486 non-null   object
#  9   route_link     3486 non-null   object
# dtypes: object(10)
# memory usage: 272.5+ KB

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\astc_routs.csv")
new
# Out:
#                                             astc_keys  \
# 0   https://www.redbus.in/bus-tickets/tezpur-to-gu...
# 1   https://www.redbus.in/bus-tickets/guwahati-to-...
# 2   https://www.redbus.in/bus-tickets/nagaon-to-gu...
# 3   https://www.redbus.in/bus-tickets/guwahati-to-...
# 4   https://www.redbus.in/bus-tickets/goalpara-to-...
# 5   https://www.redbus.in/bus-tickets/jorhat-to-no...
# 6   https://www.redbus.in/bus-tickets/dhubri-to-gu...
# 7   https://www.redbus.in/bus-tickets/guwahati-to-...
# 8   https://www.redbus.in/bus-tickets/north-lakhim...
# 9   https://www.redbus.in/bus-tickets/north-lakhim...
# 10  https://www.redbus.in/bus-tickets/dhekiajuli-t...
# 11  https://www.redbus.in/bus-tickets/jorhat-to-di...
# 12  https://www.redbus.in/bus-tickets/jorhat-to-dh...
# 13  https://www.redbus.in/bus-tickets/sibsagar-to-...
# 14  https://www.redbus.in/bus-tickets/dhemaji-to-j...
# 15  https://www.redbus.in/bus-tickets/tezpur-to-di...
# ...

# %%
#------------------------------------------------------------------------ astc ----------------------------------------------------------------------------

driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

as_bus_name=[]
as_bus_type=[]
as_bus_departing_time=[]
as_bus_duration=[]
as_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in new.iterrows():
    links=k["astc_keys"]
    routs=k["astc_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)
    for website in websites:
        website.click()
        time.sleep(2)
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='button']"))
        inside.click()
    except:
        continue
    time.sleep(3)
    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(10, document.body.scrollHeight);")
        time.sleep(8) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        #time.sleep(2)
    bus_name=driver.find_elements(By.XPATH,"//*[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//*[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//*[@class='clearfix row-one']/*[@class='column-six p-right-10 w-10 fl']")    
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//*[contains(@class,'seat-left')]")     
    for bus in bus_name:
        as_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        as_bus_type.append(bus_types.text)
    for starting_times in starting:
        as_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        as_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        as_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)

print("success")
# Out:
# success

# %%
data2={
"bus_name":as_bus_name,
"bus_type":as_bus_type,
"starting_time":as_bus_departing_time,
"time_duration":as_bus_duration,
"reaching_time":as_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
astc=pd.DataFrame(data2)
location=r"D:\total project\astc_routes.csv"
astc.to_csv(location,index=False)

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\hrtc_routs.csv")
new
# Out:
#                                             hrtc_keys  \
# 0   https://www.redbus.in/bus-tickets/delhi-to-shimla
# 1   https://www.redbus.in/bus-tickets/shimla-to-delhi
# 2   https://www.redbus.in/bus-tickets/manali-to-ch...
# 3   https://www.redbus.in/bus-tickets/chandigarh-t...
# 4   https://www.redbus.in/bus-tickets/delhi-to-manali
# 5   https://www.redbus.in/bus-tickets/hamirpur-him...
# 6   https://www.redbus.in/bus-tickets/delhi-to-ham...
# 7   https://www.redbus.in/bus-tickets/delhi-to-cha...
# 8   https://www.redbus.in/bus-tickets/manali-to-delhi
# 9   https://www.redbus.in/bus-tickets/hamirpur-him...
# 10  https://www.redbus.in/bus-tickets/chandigarh-t...
# 11  https://www.redbus.in/bus-tickets/shimla-to-ma...
# 12  https://www.redbus.in/bus-tickets/delhi-to-dha...
# 13  https://www.redbus.in/bus-tickets/shimla-to-ch...
# 14  https://www.redbus.in/bus-tickets/chandigarh-t...
# 15  https://www.redbus.in/bus-tickets/delhi-to-bad...
# ...

# %%
#---------------------------------------------------------------- hrtc ------------------------------------------------------------------------------
driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

hr_bus_name=[]
hr_bus_type=[]
hr_bus_departing_time=[]
hr_bus_duration=[]
hr_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
# count=0
# while count<len(a):
for i,k in new.iterrows():
    links=k["hrtc_keys"]
    routs=k["hrtc_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)
    for website in websites:
        website.click()
        time.sleep(2)
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='button']"))
        inside.click()
    except:
        continue
    time.sleep(3)
    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(10, document.body.scrollHeight);")
        time.sleep(10) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    bus_name=driver.find_elements(By.XPATH,"//div[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//div[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//div[@class='clearfix row-one']/div[@class='column-six p-right-10 w-10 fl']")    
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//div[contains(@class,'seat-left')]")     
    for bus in bus_name:
        hr_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        hr_bus_type.append(bus_types.text)
    for starting_times in starting:
        hr_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        hr_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        hr_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")
# Out:
# success

# %%
data3={
"bus_name":hr_bus_name,
"bus_type":hr_bus_type,
"starting_time":hr_bus_departing_time,
"time_duration":hr_bus_duration,
"reaching_time":hr_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
hrtc=pd.DataFrame(data3)
location=r"D:\total project\hrtc_routes.csv"
hrtc.to_csv(location,index=False)

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\kerala_routs.csv")
new
# Out:
#                                          kearala_keys  \
# 0   https://www.redbus.in/bus-tickets/bangalore-to...
# 1   https://www.redbus.in/bus-tickets/kozhikode-to...
# 2   https://www.redbus.in/bus-tickets/kozhikode-to...
# 3   https://www.redbus.in/bus-tickets/ernakulam-to...
# 4   https://www.redbus.in/bus-tickets/kozhikode-to...
# 5   https://www.redbus.in/bus-tickets/kozhikode-to...
# 6   https://www.redbus.in/bus-tickets/bangalore-to...
# 7   https://www.redbus.in/bus-tickets/mysore-to-ko...
# 8   https://www.redbus.in/bus-tickets/kalpetta-to-...
# 9   https://www.redbus.in/bus-tickets/kozhikode-to...
# 10  https://www.redbus.in/bus-tickets/thiruvananth...
# 11  https://www.redbus.in/bus-tickets/bangalore-to...
# 12  https://www.redbus.in/bus-tickets/kozhikode-to...
# 13  https://www.redbus.in/bus-tickets/kannur-to-ba...
# 14  https://www.redbus.in/bus-tickets/kottayam-to-...
# 15  https://www.redbus.in/bus-tickets/thrissur-to-...
# ...

# %%
#----------------------------------------------------------------- kerala -------------------------------------------------------------------
driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

kl_bus_name=[]
kl_bus_type=[]
kl_bus_departing_time=[]
kl_bus_duration=[]
kl_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in new.iterrows():
    links=k["kearala_keys"]
    routs=k["kerala_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)
    for website in websites:
        website.click()
        time.sleep(2)
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='button']"))
        inside.click()
    except:
        continue
    time.sleep(3)
    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(10) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    bus_name=driver.find_elements(By.XPATH,"//*[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//*[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//*[@class='clearfix row-one']/*[@class='column-six p-right-10 w-10 fl']")    
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//*[contains(@class,'seat-left')]")     
    for bus in bus_name:
        kl_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        kl_bus_type.append(bus_types.text)
    for starting_times in starting:
        kl_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        kl_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        kl_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")
# Out:
# success

# %%
data4={
"bus_name":kl_bus_name,
"bus_type":kl_bus_type,
"starting_time":kl_bus_departing_time,
"time_duration":kl_bus_duration,
"reaching_time":kl_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
kerala=pd.DataFrame(data4)
location=r"D:\total project\kerala_routes.csv"
kerala.to_csv(location,index=False)

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\ktcl_routs.csv")
new
# Out:
#                                             ktcl_keys  \
# 0       https://www.redbus.in/bus-tickets/pune-to-goa
# 1       https://www.redbus.in/bus-tickets/goa-to-pune
# 2     https://www.redbus.in/bus-tickets/mumbai-to-goa
# 3     https://www.redbus.in/bus-tickets/goa-to-mumbai
# 4   https://www.redbus.in/bus-tickets/pandharpur-t...
# 5   https://www.redbus.in/bus-tickets/bangalore-to...
# 6   https://www.redbus.in/bus-tickets/goa-to-pandh...
# 7   https://www.redbus.in/bus-tickets/belagavi-to-goa
# 8   https://www.redbus.in/bus-tickets/goa-to-banga...
# 9    https://www.redbus.in/bus-tickets/solapur-to-goa
# 10  https://www.redbus.in/bus-tickets/goa-to-kolha...
# 11   https://www.redbus.in/bus-tickets/goa-to-solapur
# 12   https://www.redbus.in/bus-tickets/goa-to-sangola
# 13   https://www.redbus.in/bus-tickets/sangola-to-goa
# 14  https://www.redbus.in/bus-tickets/calangute-go...
# 15    https://www.redbus.in/bus-tickets/goa-to-sangli
# ...

# %%
#----------------------------------------------------------------- ktcl -------------------------------------------------------------------
driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

kt_bus_name=[]
kt_bus_type=[]
kt_bus_departing_time=[]
kt_bus_duration=[]
kt_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in new.iterrows():
    links=k["ktcl_keys"]
    routs=k["ktcl_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)

    for website in websites:
        website.click()
    time.sleep(3)
    WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='button']"))
        inside.click()
    except:
        print("Button not found")
    time.sleep(3)
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(50, document.body.scrollHeight);")
        time.sleep(8) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        #time.sleep(2)
    bus_name=driver.find_elements(By.XPATH,"//*[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//*[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//*[@class='clearfix row-one']/*[@class='column-six p-right-10 w-10 fl']")
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")  
    seats_avail=driver.find_elements(By.XPATH,"//*[contains(@class,'seat-left')]")     
    for bus in bus_name:
        kt_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        kt_bus_type.append(bus_types.text)
    for starting_times in starting:
        kt_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        kt_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        kt_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")
# Out:
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# Button not found
# success

# %%
# length=(max(len(kt_bus_duration),len(kt_bus_departing_time),len(kt_bus_reaching_time),len(star_rating),len(price_list),len(seat_availability),len(kt_bus_name),len(route_name),len(route_link),len(kt_bus_type)))
# kt_bus_duration+=[None]*(length-len(kt_bus_duration))
# kt_bus_departing_time+=[None]*(length-len(kt_bus_departing_time))
# kt_bus_reaching_time+=[None]*(length-len(kt_bus_reaching_time))
# star_rating+=[None]*(length-len(star_rating))
# price_list+=[None]*(length-len(price_list))
# seat_availability+=[None]*(length-len(seat_availability))
# kt_bus_type+=[None]*(length-len(kt_bus_type))
# route_name+=[None]*(length-len(route_name))
# kt_bus_name+=[None]*(length-len(kt_bus_name))
# route_link+=[None]*(length-len(route_link))

# %%
data5={
"bus_name":kt_bus_name,
"bus_type":kt_bus_type,
"starting_time":kt_bus_departing_time,
"time_duration":kt_bus_duration,
"reaching_time":kt_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_names":route_name,
"route_links":route_link}
new_ktcl=pd.DataFrame(data5)
location=r"D:\total project\ktcl_routes.csv"
new_ktcl.to_csv(location,index=False)

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\rsrtc_routs.csv")
new
# Out:
#                                            rsrtc_keys  \
# 0   https://www.redbus.in/bus-tickets/jodhpur-to-a...
# 1   https://www.redbus.in/bus-tickets/beawer-to-ja...
# 2   https://www.redbus.in/bus-tickets/udaipur-to-j...
# 3   https://www.redbus.in/bus-tickets/jaipur-to-jo...
# 4   https://www.redbus.in/bus-tickets/sikar-to-jaipur
# 5   https://www.redbus.in/bus-tickets/kishangarh-t...
# 6   https://www.redbus.in/bus-tickets/aligarh-utta...
# 7   https://www.redbus.in/bus-tickets/jodhpur-to-b...
# 8   https://www.redbus.in/bus-tickets/kota-rajasth...
# 9   https://www.redbus.in/bus-tickets/jaipur-to-al...
# 10  https://www.redbus.in/bus-tickets/jaipur-to-ko...
# 11  https://www.redbus.in/bus-tickets/pali-to-udaipur
# 12  https://www.redbus.in/bus-tickets/udaipur-to-p...
# 13  https://www.redbus.in/bus-tickets/sikar-to-bik...
# 14  https://www.redbus.in/bus-tickets/jaipur-to-bh...
# 15  https://www.redbus.in/bus-tickets/kishangarh-t...
# ...

# %%
#----------------------------------------------------------------- rsrtc -------------------------------------------------------------------
driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

rs_bus_name=[]
rs_bus_type=[]
rs_bus_departing_time=[]
rs_bus_duration=[]
rs_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in new.iterrows():
    links=k["rsrtc_keys"]
    routs=k["rsrtc_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    for website in websites:
        website.click()
        time.sleep(3)
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='button']"))
        inside.click()

    except:
        print("No button found")
    time.sleep(3)    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(10, document.body.scrollHeight);")
        time.sleep(8) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
        #time.sleep(7)
    bus_name=driver.find_elements(By.XPATH,"//*[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//*[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")        
    try:
        rating=driver.find_elements(By.XPATH,"//div[@class='clearfix row-one']//*[@class='column-six p-right-10 w-10 fl']")    

    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//*[contains(@class,'seat-left')]")    
    for bus in bus_name:
        rs_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        rs_bus_type.append(bus_types.text)
    for starting_times in starting:
        rs_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        rs_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        rs_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")
# Out:
# success

# %%
length=(max(len(rs_bus_duration),len(rs_bus_departing_time),len(rs_bus_reaching_time),len(star_rating),len(price_list),len(seat_availability),len(rs_bus_name),len(route_name),len(route_link),len(rs_bus_type)))
rs_bus_duration+=[None]*(length-len(rs_bus_duration))
rs_bus_departing_time+=[None]*(length-len(rs_bus_departing_time))
rs_bus_reaching_time+=[None]*(length-len(rs_bus_reaching_time))
star_rating+=[None]*(length-len(star_rating))
price_list+=[None]*(length-len(price_list))
seat_availability+=[None]*(length-len(seat_availability))
rs_bus_type+=[None]*(length-len(rs_bus_type))
route_name+=[None]*(length-len(route_name))
rs_bus_name+=[None]*(length-len(rs_bus_name))
route_link+=[None]*(length-len(route_link))

# %%
data6={
"bus_name":rs_bus_name,
"bus_type":rs_bus_type,
"starting_time":rs_bus_departing_time,
"time_duration":rs_bus_duration,
"reaching_time":rs_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
rsrtc=pd.DataFrame(data6)
location=r"D:\total project\rsrtc_routes.csv"
rsrtc.to_csv(location,index=False)

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\sbstc_routs.csv")
new
# Out:
#                                            sbstc_keys  \
# 0   https://www.redbus.in/bus-tickets/burdwan-to-k...
# 1   https://www.redbus.in/bus-tickets/kolkata-to-b...
# 2   https://www.redbus.in/bus-tickets/durgapur-to-...
# 3   https://www.redbus.in/bus-tickets/kolkata-to-h...
# 4   https://www.redbus.in/bus-tickets/haldia-to-ko...
# 5   https://www.redbus.in/bus-tickets/kolkata-to-d...
# 6   https://www.redbus.in/bus-tickets/kolkata-to-a...
# 7   https://www.redbus.in/bus-tickets/digha-to-kol...
# 8   https://www.redbus.in/bus-tickets/kolkata-to-d...
# 9   https://www.redbus.in/bus-tickets/kolkata-to-b...
# 10  https://www.redbus.in/bus-tickets/asansol-to-k...
# 11  https://www.redbus.in/bus-tickets/midnapore-to...
# 12  https://www.redbus.in/bus-tickets/kolkata-to-a...
# 13  https://www.redbus.in/bus-tickets/kolkata-to-s...
# 14  https://www.redbus.in/bus-tickets/kolkata-to-n...
# 15  https://www.redbus.in/bus-tickets/siliguri-to-...
# ...

# %%
#----------------------------------------------------------------- sbstc -------------------------------------------------------------------
driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

ab_bus_name=[]
ab_bus_type=[]
ab_bus_departing_time=[]
ab_bus_duration=[]
ab_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in new.iterrows():
    links=k["sbstc_keys"]
    routs=k["sbstc_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)
    for website in websites:
        website.click()
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
        time.sleep(2)
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='clearfix']//div[@class='button']"))
        inside.click()
    except:
        print("button not available")
    time.sleep(3)    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(10, document.body.scrollHeight);")
        time.sleep(8) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    bus_name=driver.find_elements(By.XPATH,"//*[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//*[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//*[@class='clearfix row-one']//*[@class='column-six p-right-10 w-10 fl']")    
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//*[contains(@class,'seat-left')]")     
    for bus in bus_name:
        ab_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        ab_bus_type.append(bus_types.text)
    for starting_times in starting:
        ab_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        ab_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        ab_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")
# Out:
# success

# %%
data7={
"bus_name":ab_bus_name,
"bus_type":ab_bus_type,
"starting_time":ab_bus_departing_time,
"time_duration":ab_bus_duration,
"reaching_time":ab_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
sbstc=pd.DataFrame(data7)
location=r"D:\total project\sbstc_routes.csv"
sbstc.to_csv(location,index=False)

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\tsrtc_routs.csv")
new
# Out:
#                                            tsrtc_keys  \
# 0   https://www.redbus.in/bus-tickets/khammam-to-h...
# 1   https://www.redbus.in/bus-tickets/hyderabad-to...
# 2   https://www.redbus.in/bus-tickets/hyderabad-to...
# 3   https://www.redbus.in/bus-tickets/hyderabad-to...
# 4   https://www.redbus.in/bus-tickets/karimnagar-t...
# 5   https://www.redbus.in/bus-tickets/hyderabad-to...
# 6   https://www.redbus.in/bus-tickets/hyderabad-to...
# 7   https://www.redbus.in/bus-tickets/hyderabad-to...
# 8   https://www.redbus.in/bus-tickets/hyderabad-to...
# 9   https://www.redbus.in/bus-tickets/kothagudem-t...
# 10  https://www.redbus.in/bus-tickets/guntur-to-hy...
# 11  https://www.redbus.in/bus-tickets/godavarikhan...
# 12  https://www.redbus.in/bus-tickets/kodad-to-hyd...
# 13  https://www.redbus.in/bus-tickets/hyderabad-to...
# 14  https://www.redbus.in/bus-tickets/hyderabad-to...
# 15  https://www.redbus.in/bus-tickets/jagityal-to-...
# ...

# %%
#----------------------------------------------------------------- tsrtc -------------------------------------------------------------------
driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

ts_bus_name=[]
ts_bus_type=[]
ts_bus_departing_time=[]
ts_bus_duration=[]
ts_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in new.iterrows():
    links=k["tsrtc_keys"]
    routs=k["tsrtc_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)
    for website in websites:
        website.click()
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
        time.sleep(2)
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='clearfix']//div[@class='button']"))
        inside.click()
    except:
        print('button not available')
    time.sleep(3)    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(10, document.body.scrollHeight);")
        time.sleep(8) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    bus_name=driver.find_elements(By.XPATH,"//*[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//*[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//*[@class='clearfix row-one']//*[@class='column-six p-right-10 w-10 fl']")    
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//*[contains(@class,'seat-left')]")    
    
    for bus in bus_name:
        ts_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        ts_bus_type.append(bus_types.text)
    for starting_times in starting:
        ts_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        ts_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        ts_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")

# %%
data8={
"bus_name":ts_bus_name,
"bus_type":ts_bus_type,
"starting_time":ts_bus_departing_time,
"time_duration":ts_bus_duration,
"reaching_time":ts_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
tsrtc=pd.DataFrame(data8)
location=r"D:\total project\tsrtc_routs.csv"
tsrtc.to_csv(location,index=False)

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\upsrtc_routs.csv")
new
# Out:
#                                           upsrtc_keys  \
# 0   https://www.redbus.in/bus-tickets/bareilly-to-...
# 1   https://www.redbus.in/bus-tickets/aligarh-utta...
# 2   https://www.redbus.in/bus-tickets/delhi-to-bar...
# 3   https://www.redbus.in/bus-tickets/delhi-to-ali...
# 4   https://www.redbus.in/bus-tickets/farrukhabad-...
# 5   https://www.redbus.in/bus-tickets/badaun-to-delhi
# 6   https://www.redbus.in/bus-tickets/lucknow-to-a...
# 7   https://www.redbus.in/bus-tickets/lucknow-to-v...
# 8   https://www.redbus.in/bus-tickets/delhi-to-badaun
# 9   https://www.redbus.in/bus-tickets/agra-to-bare...
# 10  https://www.redbus.in/bus-tickets/allahabad-to...
# 11  https://www.redbus.in/bus-tickets/sitapur-to-d...
# 12  https://www.redbus.in/bus-tickets/delhi-to-far...
# 13  https://www.redbus.in/bus-tickets/moradabad-to...
# 14  https://www.redbus.in/bus-tickets/delhi-to-har...
# 15  https://www.redbus.in/bus-tickets/delhi-to-sit...
# ...

# %%
#----------------------------------------------------------------- upsrtc -------------------------------------------------------------------
driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

up_bus_name=[]
up_bus_type=[]
up_bus_departing_time=[]
up_bus_duration=[]
up_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in new.iterrows():
    links=k["upsrtc_keys"]
    routs=k["upsrtc_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)
    for website in websites:
        website.click()
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
        time.sleep(2)
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='clearfix']//div[@class='button']"))
        inside.click()
    except:
        print("button not available")
    time.sleep(3)    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(10, document.body.scrollHeight);")
        time.sleep(8) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    bus_name=driver.find_elements(By.XPATH,"//*[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//*[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//*[@class='clearfix row-one']//*[@class='column-six p-right-10 w-10 fl']")    
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//*[contains(@class,'seat-left')]")    
    
    for bus in bus_name:
        up_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        up_bus_type.append(bus_types.text)
    for starting_times in starting:
        up_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        up_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        up_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")
# Out:
# success

# %%
data9={
"bus_name":up_bus_name,
"bus_type":up_bus_type,
"starting_time":up_bus_departing_time,
"time_duration":up_bus_duration,
"reaching_time":up_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
upsrtc=pd.DataFrame(data9)
location=r"D:\total project\upsrtc_routs.csv"
upsrtc.to_csv(location,index=False)

# %%
import pandas as pd
new=pd.read_csv(r"D:\project\wbtc_routs.csv")
new
# Out:
#                                             wbtc_keys  \
# 0   https://www.redbus.in/bus-tickets/durgapur-to-...
# 1   https://www.redbus.in/bus-tickets/digha-to-bar...
# 2   https://www.redbus.in/bus-tickets/barasat-west...
# 3   https://www.redbus.in/bus-tickets/suri-to-kolkata
# 4   https://www.redbus.in/bus-tickets/kolkata-to-d...
# 5   https://www.redbus.in/bus-tickets/bolpur-west-...
# 6   https://www.redbus.in/bus-tickets/kolkata-to-suri
# 7   https://www.redbus.in/bus-tickets/digha-to-kol...
# 8   https://www.redbus.in/bus-tickets/kolkata-to-d...
# 9    https://www.redbus.in/bus-tickets/habra-to-digha
# 10  https://www.redbus.in/bus-tickets/barasat-west...
# 11  https://www.redbus.in/bus-tickets/asansol-to-k...
# 12  https://www.redbus.in/bus-tickets/barasat-west...
# 13  https://www.redbus.in/bus-tickets/siliguri-to-...
# 14  https://www.redbus.in/bus-tickets/kolkata-to-b...
# 15  https://www.redbus.in/bus-tickets/barasat-west...
# ...

# %%
#----------------------------------------------------------------- wbtc -------------------------------------------------------------------
driver=webdriver.Chrome()
wait=WebDriverWait(driver,20)
driver.maximize_window()

wb_bus_name=[]
wb_bus_type=[]
wb_bus_departing_time=[]
wb_bus_duration=[]
wb_bus_reaching_time=[]
star_rating=[]
price_list=[]
seat_availability=[]
route_name=[]
route_link=[]
for i,k in new.iterrows():
    links=k["wbtc_keys"]
    routs=k["wbtc_routes"]
    driver.get(links)
    time.sleep(5)
    websites=driver.find_elements(By.XPATH,f"//a[contains(@href,'{links}')]")
    time.sleep(2)
    for website in websites:
        website.click()
        WebDriverWait(driver,20).until(Ec.presence_of_all_elements_located((By.XPATH,"//*[@class='result-sec']")))
        time.sleep(2)
    try:
        inside=(driver.find_element(By.XPATH,"//div[@class='clearfix']//div[@class='button']"))
        inside.click()
    except:
        print("button not available")
    time.sleep(3)    
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(10, document.body.scrollHeight);")
        time.sleep(8) 
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height
    
    bus_name=driver.find_elements(By.XPATH,"//*[@class='travels lh-24 f-bold d-color']")    
    bus_type=driver.find_elements(By.XPATH,"//*[@class='bus-type f-12 m-top-16 l-color evBus']")    
    starting=driver.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")    
    duration=driver.find_elements(By.XPATH,"//*[@class='dur l-color lh-24']")    
    ending=driver.find_elements(By.XPATH,"//*[@class='bp-time f-19 d-color disp-Inline']")    
    try:
        rating=driver.find_elements(By.XPATH,"//*[@class='clearfix row-one']//*[@class='column-six p-right-10 w-10 fl']")    
    except:
        continue
    price=driver.find_elements(By.XPATH,"//*[@class='fare d-block']")    
    seats_avail=driver.find_elements(By.XPATH,"//*[contains(@class,'seat-left')]")    
    
    for bus in bus_name:
        wb_bus_name.append(bus.text)
        route_name.append(routs)
        route_link.append(links)
    for bus_types in bus_type:
        wb_bus_type.append(bus_types.text)
    for starting_times in starting:
        wb_bus_departing_time.append(starting_times.text)
    for travelling_time in duration:
        wb_bus_duration.append(travelling_time.text)
    for ending_time in ending:
        wb_bus_reaching_time.append(ending_time.text)
    for ratings in rating:
        star_rating.append(ratings.text)
    for pricing in price:
        price_list.append(pricing.text)
    for seats in seats_avail:
        seat_availability.append(seats.text)
print("success")
# Out:
# success

# %%
data10={
"bus_name":wb_bus_name,
"bus_type":wb_bus_type,
"starting_time":wb_bus_departing_time,
"time_duration":wb_bus_duration,
"reaching_time":wb_bus_reaching_time,
"rating":star_rating,
"fair_price":price_list,
"seats":seat_availability,
"route_name":route_name,
"route_link":route_link}
wbtc=pd.DataFrame(data10)
location=r"D:\total project\wbtc_routs.csv"
wbtc.to_csv(location,index=False)

# %%
import pandas as pd

# %%
wbtc=pd.read_csv(r"D:\total project\wbtc_routes.csv")
andra=pd.read_csv(r"D:\total project\andra_routes.csv")
astc=pd.read_csv(r"D:\total project\astc_routes.csv")
hrtc=pd.read_csv(r"D:\total project\hrtc_routes.csv")
kerala=pd.read_csv(r"D:\total project\kerala_routes.csv")
ktcl=pd.read_csv(r"D:\total project\ktcl_routes.csv")
rsrtc=pd.read_csv(r"D:\total project\rsrtc_routes.csv")
sbstc=pd.read_csv(r"D:\total project\sbstc_routes.csv")
tsrtc=pd.read_csv(r"D:\total project\tsrtc_routes.csv")
upsrtc=pd.read_csv(r"D:\total project\upsrtc_routes.csv")

# %%
total_bus=pd.concat([andra,astc,hrtc,kerala,ktcl,rsrtc,sbstc,tsrtc,upsrtc,wbtc],ignore_index=True)

# %%
total_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8752 entries, 0 to 8751
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bus_name       8369 non-null   object
#  1   bus_type       8358 non-null   object
#  2   starting_time  8369 non-null   object
#  3   time_duration  8369 non-null   object
#  4   reaching_time  8369 non-null   object
#  5   rating         8362 non-null   object
#  6   fair_price     8368 non-null   object
#  7   seats          8358 non-null   object
#  8   route_link     8752 non-null   object
#  9   route_name     8752 non-null   object
# dtypes: object(10)
# memory usage: 683.9+ KB

# %%
total_bus.drop(['route_links'],axis=1,inplace=True)
# location=r"D:\total project\Total.csv"
# d.to_csv(location,index=True)

# %%
total_bus["route_name"].unique()
# Out:
# array(['Vijayawada to Hyderabad', 'Hyderabad to Vijayawada',
#        'Kakinada to Visakhapatnam', 'Visakhapatnam to Kakinada',
#        'Chittoor (Andhra Pradesh) to Bangalore', 'Kadapa to Bangalore',
#        'Anantapur (andhra pradesh) to Bangalore', 'Tirupati to Bangalore',
#        'Visakhapatnam to Vijayawada', 'Ongole to Hyderabad',
#        'Bangalore to Tirupati', 'Macherla (andhra pradesh) to Hyderabad',
#        'Rajahmundry to Visakhapatnam', 'Nandyal to Hyderabad',
#        'Bangalore to Kadapa', 'Hyderabad to Ongole',
#        'Guntur (Andhra Pradesh) to Hyderabad',
#        'Vijayawada to Visakhapatnam', 'Rajahmundry to Vijayawada',
#        'Hyderabad to Kurnool', 'Bangalore to Chittoor (Andhra Pradesh)',
#        'Kurnool to Hyderabad', 'Visakhapatnam to Rajahmundry',
#        'Rayachoti to Bangalore', 'Vinukonda to Hyderabad',
#        'Bangalore to Anantapur (andhra pradesh)',
#        'Amalapuram to Visakhapatnam', 'Vijayawada to Tirupati',
# ...

# %%
#total_bus.drop("Unnamed: 0",axis=1)
total_bus["rating"]=total_bus["rating"].str.replace("New",'')
total_bus["rating"]=total_bus["rating"].str.strip()
total_bus["rating"]=pd.to_numeric(total_bus["rating"],errors='coerce')
total_bus["rating"]=total_bus["rating"].fillna(0)
total_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8752 entries, 0 to 8751
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bus_name       8369 non-null   object
#  1   bus_type       8358 non-null   object
#  2   starting_time  8369 non-null   object
#  3   time_duration  8369 non-null   object
#  4   reaching_time  8369 non-null   object
#  5   rating         8752 non-null   float64
#  6   fair_price     8368 non-null   object
#  7   seats          8358 non-null   object
#  8   route_link     8752 non-null   object
#  9   route_name     8752 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 683.9+ KB

# %%
total_bus["fair_price"]=total_bus["fair_price"].str.replace('INR','')
total_bus["fair_price"]=total_bus["fair_price"].astype(float)
total_bus["fair_price"].fillna(0)
# Out:
# 0        469.0
# 1        720.0
# 2        469.0
# 3        469.0
# 4        469.0
#          ...
# 8747    1499.0
# 8748    1000.0
# 8749     523.0
# 8750     380.0
# 8751     740.0
# Name: fair_price, Length: 8752, dtype: float64

# %%
total_bus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8752 entries, 0 to 8751
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bus_name       8369 non-null   object
#  1   bus_type       8358 non-null   object
#  2   starting_time  8369 non-null   object
#  3   time_duration  8369 non-null   object
#  4   reaching_time  8369 non-null   object
#  5   rating         8752 non-null   float64
#  6   fair_price     8368 non-null   float64
#  7   seats          8358 non-null   object
#  8   route_link     8752 non-null   object
#  9   route_name     8752 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 683.9+ KB

# %%
bus_data=total_bus.dropna()
bus_data
# Out:
#               bus_name                                    bus_type  \
# 0        APSRTC - 3589  Super Luxury (Non AC Seater 2+2 Push Back)
# 1        APSRTC - 3581  AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 2        APSRTC - 1446  Super Luxury (Non AC Seater 2+2 Push Back)
# 3        APSRTC - 3882  Super Luxury (Non AC Seater 2+2 Push Back)
# 4        APSRTC - 3593  Super Luxury (Non AC Seater 2+2 Push Back)
# ...                ...                                         ...
# 8747      Express Line     Volvo 9600 Multi-Axle A/C Sleeper (2+1)
# 8748  Maulik Paribahan                  A/C Seater / Sleeper (2+2)
# 8749     Royal Cruiser                      Volvo A/C Seater (2+2)
# 8750    Beauty Travels              NON A/C Seater / Sleeper (2+2)
# 8751  Maharani Travels                  A/C Seater / Sleeper (2+1)
#
#      starting_time time_duration reaching_time  rating  fair_price  \
# 0            07:15       08h 25m         15:40     0.0       469.0
# ...

# %%
# new1=pd.read_csv(r"D:\total project\bus_data.csv")
# new=new1.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1)
# new.info()
location=r"D:\total project\bus_data.csv"
bus_data.to_csv(location)
